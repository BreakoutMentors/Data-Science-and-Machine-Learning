# %% [markdown]
# <a href="https://colab.research.google.com/github/BreakoutMentors/Data-Science-and-Machine-Learning/blob/main/basics/challenges/OOP_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Note: Always open in Colab for the best learning experience.

# %% [markdown]
# # Object-Oriented Programming Challenge
#
# Here you will build an Object-Oriented Programming that will be inherited in multiple steps.
#
# Please look at the graph below to see how your classes will be organized.

# %%
import graphviz
graph = graphviz.Digraph(name='Inheritance Graph')

graph.edge('Vehicle', 'Motorcycle')
graph.edge('Vehicle', 'Car')
graph.edge('Car', 'Pickup Truck')
graph

# %% [markdown]
# So Vehicle is the base class, then Motorcycle and Car will inherit from Vehicle and Pickup Truck will inherit from Car.
#
# The reason why it is organized by this is because the level of specifity increases the more subclasses you create. For example, both motorcycles and cars are vehicles but they both have different amount of wheels. And Pickup Trucks are closely related to Cars that they have four wheels but only Pickup Trucks have trunk beds. You will learn how to create your classes and organize them accordingly.

# %% [markdown]
# ## Vehicle Class
#
# Vehicle class will hold information that pertains to all vehicles and you will save those as attributes. Then you can do actions like drive the vehicle, so that will be a method. Other methods will be accessor methods that will return information about the vehicle.
#
# This will be the attributes:
# 1. Number of wheels (`self.num_wheels`)
# 2. Number of seats (`self.num_seats`)
# 3. Color (`self.color`)
# 4. Name of person who owns it (`self.owner`)
#
# This will be the methods:
# 1. Drive vehicle a certain amount of miles: `.drive(miles)`
# 2. Get number of wheels: `.get_num_wheels()`
# 3. Get number of seats: `.get_num_seats()`
# 3. Get color: `.get_color()`
# 4. Get Owners name: `.get_owner()`
#
# I am going to give you the overall structure but you must fill out the rest.

# %%
class Vehicle():
    # Defining Constructor
    def __init__(self, num_wheels, num_seats, color, owners_name):
        # After taking data from the parameters, you need to save that data in attributes
        self.num_wheels = num_wheels

        # TODO: Create the other attributes

    # Defining Methods
    def drive(self, miles):
        print("{}'s Vehicle drove {} miles".format(self.owner, miles))

    def get_num_wheels(self):
        return self.num_wheels

    # TODO: Define the other methods
    def get_num_seats(self):

    def get_color(self):
    
    def get_owner(self):
        

# After finishing class, create an instance
wheels = # TODO: Number of wheels for your vehicle
color = # TODO: Color of your vehicle
name = # TODO: Your name

# Create an instance using the three variables above by inserting them as parameters
my_vehicle = Vehicle(# Input Parameters)

# Testing the methods below, everything should work and cause no errors
my_vehicle.drive(5)
print('Number of wheels the vehicle has:', my_vehicle.get_num_wheels())
print('Number of seats the vehicle has:', my_vehicle.get_num_seats())
print('Color of vehicle:', my_vehicle.get_color())
print('Owners Name:', my_vehicle.owners_name())

# %% [markdown]
# If everything works with no errors, then you are ready to move on!

# %% [markdown]
# ## Motorcycle
#
# Once we are done with the Vehicle class, then you can go ahead and work on the Motorcycle class. The Motorcycle class inherits from Vehicle, but a motorcycle is more specific that it only has two wheels and one seat.
#
# This means when we create the constructor of this class, you need to call the constructor but be very specific with number of wheels and number of seats. But, a motorcycle will still be unique in terms of its color and the owner's name.
#
# We will also override the `.drive()` method by having it print something like this:
#
# ```
# my_motorcycle = Motorcycle(color='blue', owners_name='Adam')
# my_motorcycle.drive(10)
# # Code will print this:
# >> "Adam's motorcycle drove 10 miles"
# ```
#
# **There are no new attributes and methods, you will still access the attributes and methods from the parent class since you inherit from it**
#
# I will fill some of it, but you need to finish it.

# %%
class Motorcycle(Vehicle):
    # Defining Constructor
    def __init__(self, motor_color, motor_owners_name):
        # Calling constructor of the Parent class Vehicle
        super().__init__(num_wheels=2, num_seats=1, color=motor_color, owners_name=motor_owners_name)

    # TODO: overwrite drive method
    def drive(self, miles):

# After finishing class, create an instance
color = # TODO: Color of your motorcycle
name = # TODO: Your name

# Create an instance using the three variables above by inserting them as parameters
my_motorcycle = Motorcycle(# TODO: Input Parameters)

# Testing the methods below, everything should work and cause no errors
my_motorcycle.drive(5)
print('Number of wheels the motorcycle has:', my_vehicle.get_num_wheels())
print('Number of seats the motorcycle has:', my_motorcycle.get_num_seats())
print('Color of motorcycle:', my_motorcycle.get_color())
print('Owners Name:', my_motorcycle.owners_name())

# %% [markdown]
# If everything works with no errors, then you are ready to move on!

# %% [markdown]
# ## Car
#
# The Car class will work like the Motorcycle class that will inherit from Vehicle, but will have 5 seats and 4 wheels.
#
# But we are going to introduce a new attribute that contains a list that holds all passengers in the car. There will also be a two new methods. One will add a passenger to the car, but it will alert the user that the person cannot be added since the car is full. The other will drop off a passenger, it will give a message that a passenger cannot be dropped off if a person is not in the car.
#
# **You also overwrite the drive method such as in the Motorcycle class.**
#
# New Attributes:
# - Passengers in Car (`self.passengers`)
#
# New Methods:
# - Get Passengers: `.get_passengers()`
# - Add a passenger in the car: `.add_passenger()`
# - Drop off a passenger: `.drop_passenger()`

# %%
class Car(Vehicle):
    # Defining Constructor
    def __init__(self, car_color, car_owners_name):
        # Call constructor of parent class with specific color and name

        # Adding passengers attribute
        self.passengers = [car_owners_name] # It will contain the owner since that person is using their car
    
    # Methods

    # TODO: overwrite drive method
    def drive(self, miles):
    
    # TODO: finish this method
    def get_passengers(self):
    
    # TODO: finish this method
    def add_passenger(self, passenger_name):
        if # Fill this to check if car is not full:
            # If car is not yet full, append the passenger's name to self.passengers list
            # TODO: Do that here
            print('{} is now in the car'.format(passenger_name))
        else:
            print('Cannot add {} since the car is full'.format(passengers_name))

    def drop_passenger(self, passenger_name):
        if # Check if passenger_name is in the car:
            # If that person is in the car, remove them from car
            # TODO: Do that here (HINT: Use .remove() method)
            print('{} was dropped off'.format(passenger_name))
        else:
            print('Cannot remove {} from car, since that person is not in the car'.format(passenger_name))

# After finishing class, create an instance
color = # TODO: Color of your car
name = # TODO: Your name

# Create an instance using the three variables above by inserting them as parameters
my_car = Car(# Input Parameters)

# Testing the methods below, everything should work and cause no errors
my_car.drive(5)
print('Number of wheels the car has:', my_car.get_num_wheels())
print('Number of seats the car has:', my_car.get_num_seats())
print('Color of car:', my_car.get_color())
print('Owners car:', my_car.owners_name())
print('Passengers in the car:', my_car.get_passengers())

print('\nNow testing add_passenger() method')
my_car.add_passenger('Adam')
my_car.add_passenger('Kai')
my_car.add_passenger('Brian')
my_car.add_passenger('Hector')

print('\nThe car now has 5 people, so I should get the message if a person cannot be added below:')
my_car.add_passenger('Adrian')

print('\nYou are going to drop off Adam so Adrian can enter the car:')
my_car.drop_passenger('Adam')

print('\nSince Adam has been dropped off, Adrian can now be added:')
my_car.add_passenger('Adrian')

# %% [markdown]
# If everything works with no errors, then you are ready to move on!

# %% [markdown]
# ## Pickup Truck
#
# Since Pickup Truck will inherit from Car, it will contain all the same methods and attributes. But you will add new attributes and methods to do with the trunk bed of the truck.
#
# Just as a car, usually Pickup Trucks have 4 wheels and only have 5 seats, so think about that when constructing the class.
#
# **You also overwrite the drive method such as in the Motorcycle and Car class.**
#
# New Attributes:
# - If truck has Trunk Bed (`self.has_trunk`)
# - Passengers in Car (`self.items_in_trunk`)
#
# New Methods:
# - Get Items in trunk: `.get_items_in_trunk()`
# - Add item to the trunk: `.add_item_to_trunk()`
# - Remove item from a trunk: `.remove_item_from_trunk()`
#     - If item is not in trunk, then alert the user that the item does not exist

# %%
class Pickup_Truck(Car):
    # Defining Constructor
    def __init__(self, truck_color, truck_owners_name):
        # Call constructor of the parent class

        # Add has_truck and items_in_truck attributes

    
    # TODO: Finish the methods below
    def get_items_in_trunk(self):
    
    def add_items_to_trunk(self, item):
        # TODO: add item to trunk

        print('Added {} to the trunk'.format(item))

    def remove_item_from_trunk(self, item):
        if # Check if item is in trunk:
            # Remove item from list
            print('The {} was removed from the trunk'.format(item))

        else:
            # Alert the user that the item does not exist in the trunk

# After finishing class, create an instance
color = # TODO: Color of your truck
name = # TODO: Your name

# Create an instance using the three variables above by inserting them as parameters
my_truck = Pickup_Truck(# Input Parameters)

# Testing the methods below, everything should work and cause no errors
my_truck.drive(5)
print('Number of wheels the truck has:', my_truck.get_num_wheels())
print('Number of seats the truck has:', my_truck.get_num_seats())
print('Color of truck:', my_truck.get_color())
print('Owners truck:', my_truck.owners_name())
print('Passengers in the truck:', my_truck.get_passengers())

print('\nNow testing add_passenger() method')
my_truck.add_passenger('Adam')
my_truck.add_passenger('Kai')
my_truck.add_passenger('Brian')
my_truck.add_passenger('Hector')

print('\nThe truck now has 5 people, so I should get the message if a person cannot be added below:')
my_truck.add_passenger('Adrian')

print('\nYou truck going to drop off Adam so Adrian can enter the truck:')
my_truck.drop_passenger('Adam')

print('\nSince Adam has been dropped off, Adrian can now be added:')
my_truck.add_passenger('Adrian')

print('\nNow we will check if your trunk attributes and methods are working well')
print('Checking if your truck has a trunk bed (SHOULD BE TRUE):', my_truck.has_trunk)
print('\nNow two items will be added to the trunk')
my_truck.add_item_to_trunk('Shovel')
my_truck.add_item_to_trunk('Wood Planks')
print('\nNow checking if you can remove items that exist')
my_truck.remove_item_from_trunk('Shovel')
print('\nRemoving items that do not exist in trunk')
my_truck.remove_item_from_trunk('Water Cooler')

# %% [markdown]
# If everything works with no errors, then you are done with this challenge! You should now have a good understanding of how to build classes.
